# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identigy the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %%
# import the requests library
import requests

# import the weather_api_key
from config import weather_api_key

# build basic URL for the OpenWeatherMap with weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | esperance
# Processing Record 8 of Set 1 | bilibino
# Processing Record 9 of Set 1 | swift current
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | platanos
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | ullal
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | kahului
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | pitimbu
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | alice springs
# Processing Record 21 of Set 1 | donji vakuf
# Processing Record 22 of Set 1 | yarmouth
# Processing Record 23 of Set 1 | aswan
# Processing Record 24 of Set 1 | kobryn
# Processing Record 25 of Set 1 | linxia
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 29 of Set 1 | ariquemes
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | trinidad
# Processing Record 33 of Set 1 | novo mesto
# Processing Record 34 of Set 1 | orchard homes
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | batticaloa
# Processing Record 38 of Set 1 | karpathos
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | bereda
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | grindavik
# Processing Record 43 of Set 1 | braganca
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | roebourne
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | massakory
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | brae
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | marang
# Processing Record 9 of Set 2 | vredendal
# Processing Record 10 of Set 2 | labuhan
# Processing Record 11 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 2 | lavrentiya
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | susaki
# Processing Record 15 of Set 2 | voznesenye
# Processing Record 16 of Set 2 | beloha
# Processing Record 17 of Set 2 | rock springs
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | arzgir
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | katherine
# Processing Record 25 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 2 | siuna
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | ixtapa
# Processing Record 29 of Set 2 | nova londrina
# Processing Record 30 of Set 2 | namatanai
# Processing Record 31 of Set 2 | henties bay
# Processing Record 32 of Set 2 | zhigansk
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | sobolevo
# Processing Record 36 of Set 2 | kuala terengganu
# Processing Record 37 of Set 2 | mahibadhoo
# Processing Record 38 of Set 2 | kawalu
# Processing Record 39 of Set 2 | kapoeta
# Processing Record 40 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | conde
# Processing Record 45 of Set 2 | vallenar
# Processing Record 46 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 2 | alta floresta
# Processing Record 48 of Set 2 | iquitos
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | dabola
# Processing Record 2 of Set 3 | akrata
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 3 | springbok
# Processing Record 8 of Set 3 | victoria
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | zhangye
# Processing Record 12 of Set 3 | de land
# Processing Record 13 of Set 3 | baykit
# Processing Record 14 of Set 3 | akonolinga
# Processing Record 15 of Set 3 | garowe
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | shache
# Processing Record 19 of Set 3 | kedrovoye
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | santa pola
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | bethanien
# Processing Record 25 of Set 3 | arauco
# Processing Record 26 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | santa marta
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | prince rupert
# Processing Record 32 of Set 3 | ampanihy
# Processing Record 33 of Set 3 | vrede
# Processing Record 34 of Set 3 | dongsheng
# Processing Record 35 of Set 3 | calbuco
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | raozan
# City not found. Skipping...
# Processing Record 38 of Set 3 | necochea
# Processing Record 39 of Set 3 | pangnirtung
# Processing Record 40 of Set 3 | masalli
# Processing Record 41 of Set 3 | ghugus
# Processing Record 42 of Set 3 | humberto de campos
# Processing Record 43 of Set 3 | pirna
# Processing Record 44 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 3 | igunga
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | bougouni
# Processing Record 48 of Set 3 | burkhala
# City not found. Skipping...
# Processing Record 49 of Set 3 | weinan
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | kuhestan
# City not found. Skipping...
# Processing Record 2 of Set 4 | port pirie
# Processing Record 3 of Set 4 | bonavista
# Processing Record 4 of Set 4 | east london
# Processing Record 5 of Set 4 | luganville
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | benghazi
# Processing Record 9 of Set 4 | concepcion del oro
# Processing Record 10 of Set 4 | saint-joseph
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | kaseda
# Processing Record 13 of Set 4 | palmas
# Processing Record 14 of Set 4 | betsiamites
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | huaiyuan
# Processing Record 17 of Set 4 | san juan
# Processing Record 18 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 4 | ndele
# Processing Record 20 of Set 4 | fiumicino
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | ostrovnoy
# Processing Record 23 of Set 4 | morondava
# Processing Record 24 of Set 4 | gazimurskiy zavod
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | jijiga
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | bairiki
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | savannah
# Processing Record 32 of Set 4 | anloga
# Processing Record 33 of Set 4 | caxito
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | visby
# Processing Record 36 of Set 4 | kuytun
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | tautira
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | kappeln
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | kodyma
# Processing Record 45 of Set 4 | malpe
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | ulladulla
# Processing Record 49 of Set 4 | vidim
# Processing Record 50 of Set 4 | alekseyevsk
# Processing Record 1 of Set 5 | giyani
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | hermanus
# Processing Record 4 of Set 5 | lubango
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | keti bandar
# Processing Record 7 of Set 5 | awbari
# Processing Record 8 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | manali
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | sakakah
# Processing Record 14 of Set 5 | maracaibo
# Processing Record 15 of Set 5 | dingle
# Processing Record 16 of Set 5 | la ronge
# Processing Record 17 of Set 5 | bredasdorp
# Processing Record 18 of Set 5 | okha
# Processing Record 19 of Set 5 | sao jose da coroa grande
# Processing Record 20 of Set 5 | gravenhurst
# Processing Record 21 of Set 5 | hilo
# Processing Record 22 of Set 5 | huari
# Processing Record 23 of Set 5 | manokwari
# Processing Record 24 of Set 5 | kaeo
# Processing Record 25 of Set 5 | merauke
# Processing Record 26 of Set 5 | san jose
# Processing Record 27 of Set 5 | podujevo
# Processing Record 28 of Set 5 | jining
# Processing Record 29 of Set 5 | posse
# Processing Record 30 of Set 5 | mackay
# Processing Record 31 of Set 5 | el carmen
# Processing Record 32 of Set 5 | buluang
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 5 | norwich
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | pangoa
# Processing Record 40 of Set 5 | cooma
# Processing Record 41 of Set 5 | leningradskiy
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | temirtau
# Processing Record 45 of Set 5 | harkany
# Processing Record 46 of Set 5 | jinka
# Processing Record 47 of Set 5 | yining
# Processing Record 48 of Set 5 | fort-shevchenko
# Processing Record 49 of Set 5 | kefalos
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 6 | nabire
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | vao
# Processing Record 5 of Set 6 | saldanha
# Processing Record 6 of Set 6 | altay
# Processing Record 7 of Set 6 | tongchuan
# Processing Record 8 of Set 6 | jalu
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | komsomolets
# Processing Record 11 of Set 6 | beyneu
# Processing Record 12 of Set 6 | mumford
# Processing Record 13 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 6 | quesnel
# Processing Record 16 of Set 6 | westport
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | pacific grove
# Processing Record 19 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 6 | angoche
# Processing Record 21 of Set 6 | jipijapa
# Processing Record 22 of Set 6 | atar
# Processing Record 23 of Set 6 | bobcaygeon
# Processing Record 24 of Set 6 | wasilla
# Processing Record 25 of Set 6 | prescott valley
# Processing Record 26 of Set 6 | healesville
# Processing Record 27 of Set 6 | uruzgan
# Processing Record 28 of Set 6 | menemen
# Processing Record 29 of Set 6 | sao joao da barra
# Processing Record 30 of Set 6 | menongue
# Processing Record 31 of Set 6 | nalut
# Processing Record 32 of Set 6 | borovskoy
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | tatvan
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | luanda
# Processing Record 37 of Set 6 | kentau
# Processing Record 38 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 6 | batemans bay
# Processing Record 41 of Set 6 | port augusta
# Processing Record 42 of Set 6 | adre
# Processing Record 43 of Set 6 | culebra
# Processing Record 44 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | marawi
# Processing Record 47 of Set 6 | banyo
# Processing Record 48 of Set 6 | mikun
# Processing Record 49 of Set 6 | lac-megantic
# Processing Record 50 of Set 6 | beringovskiy
# Processing Record 1 of Set 7 | gornopravdinsk
# Processing Record 2 of Set 7 | xichang
# Processing Record 3 of Set 7 | bouca
# Processing Record 4 of Set 7 | trincomalee
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | sidi bu zayd
# City not found. Skipping...
# Processing Record 7 of Set 7 | chebsara
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | sawtell
# Processing Record 10 of Set 7 | vaini
# Processing Record 11 of Set 7 | rabo de peixe
# Processing Record 12 of Set 7 | saint anthony
# Processing Record 13 of Set 7 | north myrtle beach
# Processing Record 14 of Set 7 | alexandria
# Processing Record 15 of Set 7 | poum
# Processing Record 16 of Set 7 | milkovo
# Processing Record 17 of Set 7 | ayan
# Processing Record 18 of Set 7 | matay
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 7 | manicore
# Processing Record 22 of Set 7 | pemba
# Processing Record 23 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 24 of Set 7 | goure
# Processing Record 25 of Set 7 | bealanana
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | bima
# Processing Record 28 of Set 7 | medea
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | severo-kurilsk
# Processing Record 31 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 7 | carballo
# Processing Record 33 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | kon tum
# Processing Record 36 of Set 7 | juneau
# Processing Record 37 of Set 7 | bequimao
# Processing Record 38 of Set 7 | yeppoon
# Processing Record 39 of Set 7 | oktyabrskoye
# Processing Record 40 of Set 7 | coahuayana
# Processing Record 41 of Set 7 | boras
# Processing Record 42 of Set 7 | kismayo
# Processing Record 43 of Set 7 | caravelas
# Processing Record 44 of Set 7 | kousseri
# Processing Record 45 of Set 7 | tyssedal
# Processing Record 46 of Set 7 | saint-georges
# Processing Record 47 of Set 7 | bengkulu
# Processing Record 48 of Set 7 | esmeraldas
# Processing Record 49 of Set 7 | znamenskoye
# Processing Record 50 of Set 7 | clyde river
# Processing Record 1 of Set 8 | buraydah
# Processing Record 2 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 8 | lucapa
# Processing Record 4 of Set 8 | los llanos de aridane
# Processing Record 5 of Set 8 | san fernando
# Processing Record 6 of Set 8 | rio grande
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | puri
# Processing Record 9 of Set 8 | perepravnaya
# Processing Record 10 of Set 8 | kihei
# Processing Record 11 of Set 8 | haimen
# Processing Record 12 of Set 8 | saint-pierre
# Processing Record 13 of Set 8 | kalmunai
# Processing Record 14 of Set 8 | north branch
# Processing Record 15 of Set 8 | wajima
# Processing Record 16 of Set 8 | carutapera
# Processing Record 17 of Set 8 | hervey bay
# Processing Record 18 of Set 8 | norman wells
# Processing Record 19 of Set 8 | santa catalina
# Processing Record 20 of Set 8 | lagoa
# Processing Record 21 of Set 8 | teguldet
# Processing Record 22 of Set 8 | misratah
# Processing Record 23 of Set 8 | namangan
# Processing Record 24 of Set 8 | talnakh
# Processing Record 25 of Set 8 | san cristobal
# Processing Record 26 of Set 8 | cururupu
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | beckley
# Processing Record 29 of Set 8 | orebro
# Processing Record 30 of Set 8 | mustafakemalpasa
# Processing Record 31 of Set 8 | salinas
# Processing Record 32 of Set 8 | voyvozh
# Processing Record 33 of Set 8 | ayutthaya
# Processing Record 34 of Set 8 | abonnema
# Processing Record 35 of Set 8 | auki
# Processing Record 36 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 8 | la asuncion
# Processing Record 38 of Set 8 | lokosovo
# Processing Record 39 of Set 8 | burica
# City not found. Skipping...
# Processing Record 40 of Set 8 | san carlos de bariloche
# Processing Record 41 of Set 8 | nanortalik
# Processing Record 42 of Set 8 | husavik
# Processing Record 43 of Set 8 | kloulklubed
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | iqaluit
# Processing Record 46 of Set 8 | anadyr
# Processing Record 47 of Set 8 | darhan
# Processing Record 48 of Set 8 | chino valley
# Processing Record 49 of Set 8 | bechem
# Processing Record 50 of Set 8 | sao filipe
# Processing Record 1 of Set 9 | opuwo
# Processing Record 2 of Set 9 | conakry
# Processing Record 3 of Set 9 | muros
# Processing Record 4 of Set 9 | naze
# Processing Record 5 of Set 9 | urumqi
# Processing Record 6 of Set 9 | umm lajj
# Processing Record 7 of Set 9 | bosaso
# Processing Record 8 of Set 9 | pangkalanbuun
# Processing Record 9 of Set 9 | siderno
# Processing Record 10 of Set 9 | khasan
# Processing Record 11 of Set 9 | tocopilla
# Processing Record 12 of Set 9 | siniscola
# Processing Record 13 of Set 9 | askiz
# Processing Record 14 of Set 9 | port-gentil
# Processing Record 15 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 9 | hambantota
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | geraldton
# Processing Record 19 of Set 9 | termiz
# Processing Record 20 of Set 9 | lahaina
# Processing Record 21 of Set 9 | kandrian
# Processing Record 22 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 9 | huicungo
# Processing Record 24 of Set 9 | tabou
# Processing Record 25 of Set 9 | floro
# Processing Record 26 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 9 | lumeje
# Processing Record 28 of Set 9 | anju
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | zhengjiatun
# Processing Record 31 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | bonoua
# Processing Record 33 of Set 9 | maragogi
# Processing Record 34 of Set 9 | wote
# Processing Record 35 of Set 9 | hvolsvollur
# Processing Record 36 of Set 9 | kendari
# Processing Record 37 of Set 9 | byron bay
# Processing Record 38 of Set 9 | kirchhundem
# Processing Record 39 of Set 9 | teya
# Processing Record 40 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 41 of Set 9 | port arthur
# Processing Record 42 of Set 9 | mokhsogollokh
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | san rafael
# Processing Record 45 of Set 9 | pokhara
# Processing Record 46 of Set 9 | ghogha
# Processing Record 47 of Set 9 | kedrovyy
# Processing Record 48 of Set 9 | adrar
# Processing Record 49 of Set 9 | iranshahr
# Processing Record 50 of Set 9 | puerto leguizamo
# Processing Record 1 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 10 | kadnikov
# Processing Record 3 of Set 10 | sioux lookout
# Processing Record 4 of Set 10 | katangli
# Processing Record 5 of Set 10 | chapais
# Processing Record 6 of Set 10 | aklavik
# Processing Record 7 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 8 of Set 10 | honningsvag
# Processing Record 9 of Set 10 | siraha
# Processing Record 10 of Set 10 | poronaysk
# Processing Record 11 of Set 10 | comodoro rivadavia
# Processing Record 12 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 10 | rayadrug
# Processing Record 16 of Set 10 | swan river
# Processing Record 17 of Set 10 | flinders
# Processing Record 18 of Set 10 | murgab
# Processing Record 19 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 10 | nagornskiy
# Processing Record 21 of Set 10 | tucumcari
# Processing Record 22 of Set 10 | kiunga
# Processing Record 23 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 10 | hinton
# Processing Record 25 of Set 10 | mehamn
# Processing Record 26 of Set 10 | biak
# Processing Record 27 of Set 10 | moron
# Processing Record 28 of Set 10 | hilton head island
# Processing Record 29 of Set 10 | valdosta
# Processing Record 30 of Set 10 | toktogul
# Processing Record 31 of Set 10 | coquimbo
# Processing Record 32 of Set 10 | sorland
# Processing Record 33 of Set 10 | almaznyy
# Processing Record 34 of Set 10 | boca do acre
# Processing Record 35 of Set 10 | mahanoro
# Processing Record 36 of Set 10 | riyadh
# Processing Record 37 of Set 10 | mutsu
# Processing Record 38 of Set 10 | kapit
# Processing Record 39 of Set 10 | shizunai
# Processing Record 40 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 41 of Set 10 | richards bay
# Processing Record 42 of Set 10 | progreso
# Processing Record 43 of Set 10 | ourossogui
# Processing Record 44 of Set 10 | hofn
# Processing Record 45 of Set 10 | egvekinot
# Processing Record 46 of Set 10 | pimampiro
# Processing Record 47 of Set 10 | podhum
# Processing Record 48 of Set 10 | tuatapere
# Processing Record 49 of Set 10 | praia
# Processing Record 50 of Set 10 | gurgaon
# Processing Record 1 of Set 11 | taksimo
# Processing Record 2 of Set 11 | chiang rai
# Processing Record 3 of Set 11 | ahipara
# Processing Record 4 of Set 11 | tamiahua
# Processing Record 5 of Set 11 | vestmanna
# Processing Record 6 of Set 11 | mandalgovi
# Processing Record 7 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 11 | samdari
# Processing Record 9 of Set 11 | okhotsk
# Processing Record 10 of Set 11 | hobyo
# Processing Record 11 of Set 11 | gopalganj
# Processing Record 12 of Set 11 | devrek
# Processing Record 13 of Set 11 | svetlyy
# Processing Record 14 of Set 11 | koutiala
# Processing Record 15 of Set 11 | purpe
# Processing Record 16 of Set 11 | tomatlan
# Processing Record 17 of Set 11 | griffith
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | pochutla
# Processing Record 20 of Set 11 | guanica
# Processing Record 21 of Set 11 | viedma
# Processing Record 22 of Set 11 | brahmapuri
# City not found. Skipping...
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | shinpokh
# Processing Record 25 of Set 11 | emerald
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | palasa
# Processing Record 28 of Set 11 | elat
# Processing Record 29 of Set 11 | thompson
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | bandiagara
# Processing Record 32 of Set 11 | mozarlandia
# Processing Record 33 of Set 11 | miragoane
# Processing Record 34 of Set 11 | ngorongoro
# Processing Record 35 of Set 11 | juba
# Processing Record 36 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 11 | luwuk
# Processing Record 38 of Set 11 | dicabisagan
# Processing Record 39 of Set 11 | bose
# Processing Record 40 of Set 11 | sao gabriel da cachoeira
# Processing Record 41 of Set 11 | umm kaddadah
# Processing Record 42 of Set 11 | colares
# Processing Record 43 of Set 11 | pinotepa nacional
# Processing Record 44 of Set 11 | thinadhoo
# Processing Record 45 of Set 11 | mastic beach
# Processing Record 46 of Set 11 | alofi
# Processing Record 47 of Set 11 | maniitsoq
# Processing Record 48 of Set 11 | baran
# Processing Record 49 of Set 11 | lufilufi
# Processing Record 50 of Set 11 | lodeynoye pole
# Processing Record 1 of Set 12 | manono
# Processing Record 2 of Set 12 | mount gambier
# Processing Record 3 of Set 12 | paracuru
# Processing Record 4 of Set 12 | skegness
# Processing Record 5 of Set 12 | slave lake
# Processing Record 6 of Set 12 | rize
# Processing Record 7 of Set 12 | raga
# Processing Record 8 of Set 12 | codrington
# Processing Record 9 of Set 12 | koumac
# Processing Record 10 of Set 12 | kiama
# Processing Record 11 of Set 12 | manama
# Processing Record 12 of Set 12 | waingapu
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | chervone
# Processing Record 15 of Set 12 | matara
# Processing Record 16 of Set 12 | muroto
# Processing Record 17 of Set 12 | burnie
# Processing Record 18 of Set 12 | samana
# Processing Record 19 of Set 12 | amahai
# Processing Record 20 of Set 12 | jadu
# Processing Record 21 of Set 12 | killam
# Processing Record 22 of Set 12 | bustamante
# Processing Record 23 of Set 12 | mutoko
# Processing Record 24 of Set 12 | minab
# Processing Record 25 of Set 12 | atherton
# Processing Record 26 of Set 12 | gat
# Processing Record 27 of Set 12 | ambilobe
# Processing Record 28 of Set 12 | roald
# Processing Record 29 of Set 12 | kondinskoye
# Processing Record 30 of Set 12 | kuandian
# Processing Record 31 of Set 12 | tazovskiy
# Processing Record 32 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 12 | longyan
# Processing Record 34 of Set 12 | kuching
# Processing Record 35 of Set 12 | krasnaya gora
# Processing Record 36 of Set 12 | sogne
# Processing Record 37 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 12 | melo
# Processing Record 39 of Set 12 | san policarpo
# Processing Record 40 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 41 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 12 | fort nelson
# Processing Record 43 of Set 12 | the valley
# Processing Record 44 of Set 12 | de aar
# Processing Record 45 of Set 12 | tavda
# Processing Record 46 of Set 12 | half moon bay
# Processing Record 47 of Set 12 | evensk
# Processing Record 48 of Set 12 | dhidhdhoo
# Processing Record 49 of Set 12 | tura
# Processing Record 50 of Set 12 | kaoma
# Processing Record 1 of Set 13 | ponta delgada
# Processing Record 2 of Set 13 | pangody
# Processing Record 3 of Set 13 | krasnofarfornyy
# Processing Record 4 of Set 13 | suzaka
# Processing Record 5 of Set 13 | aqtobe
# Processing Record 6 of Set 13 | chara
# Processing Record 7 of Set 13 | cockburn town
# Processing Record 8 of Set 13 | chifeng
# Processing Record 9 of Set 13 | bosansko grahovo
# Processing Record 10 of Set 13 | trairi
# Processing Record 11 of Set 13 | palau
# Processing Record 12 of Set 13 | caiaponia
# Processing Record 13 of Set 13 | ternate
# Processing Record 14 of Set 13 | stony plain
# Processing Record 15 of Set 13 | daliao
# Processing Record 16 of Set 13 | santa isabel do rio negro
# Processing Record 17 of Set 13 | vrangel
# Processing Record 18 of Set 13 | yaan
# Processing Record 19 of Set 13 | ust-ilimsk
# Processing Record 20 of Set 13 | banff
# Processing Record 21 of Set 13 | vila
# Processing Record 22 of Set 13 | edremit
# Processing Record 23 of Set 13 | soverato
# Processing Record 24 of Set 13 | jatiroto
# Processing Record 25 of Set 13 | kuhdasht
# Processing Record 26 of Set 13 | lagunas
# Processing Record 27 of Set 13 | balkanabat
# Processing Record 28 of Set 13 | vicuna
# Processing Record 29 of Set 13 | portland
# Processing Record 30 of Set 13 | tandalti
# Processing Record 31 of Set 13 | malakal
# Processing Record 32 of Set 13 | sandnessjoen
# Processing Record 33 of Set 13 | sechura
# Processing Record 34 of Set 13 | banda aceh
# Processing Record 35 of Set 13 | shingu
# Processing Record 36 of Set 13 | ambovombe
# Processing Record 37 of Set 13 | ler
# Processing Record 38 of Set 13 | aasiaat
# Processing Record 39 of Set 13 | sinazongwe
# Processing Record 40 of Set 13 | collie
# Processing Record 41 of Set 13 | baruun-urt
# Processing Record 42 of Set 13 | san patricio
# Processing Record 43 of Set 13 | fare
# Processing Record 44 of Set 13 | tucurui
# Processing Record 45 of Set 13 | kirakira
# Processing Record 46 of Set 13 | bull savanna
# Processing Record 47 of Set 13 | nikko
# Processing Record 48 of Set 13 | marsabit
# Processing Record 49 of Set 13 | margate
# Processing Record 50 of Set 13 | orocue
# Processing Record 1 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 14 | waipawa
# Processing Record 3 of Set 14 | umea
# Processing Record 4 of Set 14 | sydney
# Processing Record 5 of Set 14 | seymchan
# Processing Record 6 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 14 | mogadishu
# Processing Record 8 of Set 14 | tahta
# Processing Record 9 of Set 14 | sutysky
# Processing Record 10 of Set 14 | chernyshevskiy
# Processing Record 11 of Set 14 | mitsamiouli
# Processing Record 12 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 13 of Set 14 | saint-louis
# Processing Record 14 of Set 14 | qasigiannguit
# Processing Record 15 of Set 14 | muli
# Processing Record 16 of Set 14 | am timan
# Processing Record 17 of Set 14 | kutum
# Processing Record 18 of Set 14 | saint-felicien
# Processing Record 19 of Set 14 | rundu
# Processing Record 20 of Set 14 | shaunavon
# Processing Record 21 of Set 14 | antofagasta
# Processing Record 22 of Set 14 | qui nhon
# Processing Record 23 of Set 14 | jacksonville
# Processing Record 24 of Set 14 | marsh harbour
# Processing Record 25 of Set 14 | lockport
# Processing Record 26 of Set 14 | broome
# Processing Record 27 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 14 | del rio
# Processing Record 29 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 14 | mangochi
# Processing Record 31 of Set 14 | bubaque
# Processing Record 32 of Set 14 | coari
# Processing Record 33 of Set 14 | kaspiyskiy
# Processing Record 34 of Set 14 | taltal
# Processing Record 35 of Set 14 | ryotsu
# Processing Record 36 of Set 14 | mrakovo
# Processing Record 37 of Set 14 | urengoy
# Processing Record 38 of Set 14 | freeport
# Processing Record 39 of Set 14 | nemuro
# Processing Record 40 of Set 14 | maceio
# Processing Record 41 of Set 14 | grants
# Processing Record 42 of Set 14 | tumen
# Processing Record 43 of Set 14 | pimentel
# Processing Record 44 of Set 14 | alakurtti
# Processing Record 45 of Set 14 | buin
# Processing Record 46 of Set 14 | bilozerka
# Processing Record 47 of Set 14 | makakilo city
# Processing Record 48 of Set 14 | at-bashi
# Processing Record 49 of Set 14 | erenhot
# Processing Record 50 of Set 14 | lewistown
# Processing Record 1 of Set 15 | fillan
# Processing Record 2 of Set 15 | vanimo
# Processing Record 3 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 4 of Set 15 | ramanuj ganj
# Processing Record 5 of Set 15 | lloydminster
# Processing Record 6 of Set 15 | haines junction
# Processing Record 7 of Set 15 | ewa beach
# Processing Record 8 of Set 15 | cabedelo
# Processing Record 9 of Set 15 | pionerskiy
# Processing Record 10 of Set 15 | sederot
# Processing Record 11 of Set 15 | paris
# Processing Record 12 of Set 15 | lincoln
# Processing Record 13 of Set 15 | pankovka
# Processing Record 14 of Set 15 | vila velha
# Processing Record 15 of Set 15 | luderitz
# Processing Record 16 of Set 15 | gaozhou
# Processing Record 17 of Set 15 | denizli
# Processing Record 18 of Set 15 | waitati
# Processing Record 19 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 15 | poplar bluff
# Processing Record 21 of Set 15 | sabang
# Processing Record 22 of Set 15 | dawson creek
# Processing Record 23 of Set 15 | launceston
# Processing Record 24 of Set 15 | hueytown
# Processing Record 25 of Set 15 | port hedland
# Processing Record 26 of Set 15 | kudahuvadhoo
# Processing Record 27 of Set 15 | sitia
# Processing Record 28 of Set 15 | amapa
# Processing Record 29 of Set 15 | vestmannaeyjar
# Processing Record 30 of Set 15 | pithoro
# Processing Record 31 of Set 15 | caucaia
# Processing Record 32 of Set 15 | taubate
# Processing Record 33 of Set 15 | plaridel
# Processing Record 34 of Set 15 | tinskoy
# Processing Record 35 of Set 15 | coihaique
# Processing Record 36 of Set 15 | itacoatiara
# Processing Record 37 of Set 15 | daru
# Processing Record 38 of Set 15 | santa cruz
# Processing Record 39 of Set 15 | praya
# Processing Record 40 of Set 15 | bilecik
# Processing Record 41 of Set 15 | tashara
# Processing Record 42 of Set 15 | arlit
# Processing Record 43 of Set 15 | batagay
# Processing Record 44 of Set 15 | mao
# Processing Record 45 of Set 15 | toora-khem
# Processing Record 46 of Set 15 | feijo
# Processing Record 47 of Set 15 | marsciano
# Processing Record 48 of Set 15 | morehead
# Processing Record 49 of Set 15 | truro
# Processing Record 50 of Set 15 | great bend
# Processing Record 1 of Set 16 | bonthe
# Processing Record 2 of Set 16 | asyut
# Processing Record 3 of Set 16 | novyy urengoy
# Processing Record 4 of Set 16 | soc trang
# Processing Record 5 of Set 16 | ipameri
# Processing Record 6 of Set 16 | le port
# Processing Record 7 of Set 16 | sao felix do xingu
# Processing Record 8 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 16 | lalmohan
# Processing Record 10 of Set 16 | netivot
# Processing Record 11 of Set 16 | vardo
# Processing Record 12 of Set 16 | namtsy
# Processing Record 13 of Set 16 | tumannyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     71.46        68          75
# 1     Longyearbyen  78.2186   15.6401     19.24        86          75
# 2       Butaritari   3.0707  172.7902     82.56        78          37
# 3        Hithadhoo  -0.6000   73.0833     82.76        72          76
# 4        Cape Town -33.9258   18.4232     67.10        60          75
# 5       Chokurdakh  70.6333  147.9167    -16.89       100          52
# 6        Esperance -33.8667  121.9000     55.78        63          30
# 7         Bilibino  68.0546  166.4372     -3.51       100         100
# 8    Swift Current  50.2834 -107.8014     22.01        93          20
# 9   Saint-Philippe -21.3585   55.7679     84.47        80          52
#
#    Wind Speed Country Current Description
# 0        3.44      BR       broken clouds
# 1       10.36      SJ       broken clouds
# 2       16.33      KI          light rain
# 3       11.27      MV       broken clouds
# 4        5.99      ZA       broken clouds
# 5        2.19      RU       broken clouds
# 6        8.99      AU    scattered clouds
# 7        2.13      RU     overcast clouds
# 8        3.44      CA                mist
# 9       10.63      RE          light rain

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        68          75
# 1     Longyearbyen      SJ  78.2186   15.6401     19.24        86          75
# 2       Butaritari      KI   3.0707  172.7902     82.56        78          37
# 3        Hithadhoo      MV  -0.6000   73.0833     82.76        72          76
# 4        Cape Town      ZA -33.9258   18.4232     67.10        60          75
# 5       Chokurdakh      RU  70.6333  147.9167    -16.89       100          52
# 6        Esperance      AU -33.8667  121.9000     55.78        63          30
# 7         Bilibino      RU  68.0546  166.4372     -3.51       100         100
# 8    Swift Current      CA  50.2834 -107.8014     22.01        93          20
# 9   Saint-Philippe      RE -21.3585   55.7679     84.47        80          52
#
#    Wind Speed Current Description
# 0        3.44       broken clouds
# 1       10.36       broken clouds
# 2       16.33          light rain
# 3       11.27       broken clouds
# 4        5.99       broken clouds
# 5        2.19       broken clouds
# 6        8.99    scattered clouds
# 7        2.13     overcast clouds
# 8        3.44                mist
# 9       10.63          light rain

# %%
# export city_data_df to csv file
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
